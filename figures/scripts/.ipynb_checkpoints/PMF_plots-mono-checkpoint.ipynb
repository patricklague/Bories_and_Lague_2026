# %%
import gzip
import glob
import csv
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

aa=['GLYD', 'SCA', 'SCV', 'SCL', 'SCI', 'SCP', 'SCHD', 'SCHE', 'SCHP', 'SCW', 'SCY', 'SCYM', 'SCM',
    'SCC', 'SCCM', 'SCF', 'SCS', 'SCT', 'SCK', 'SCKN', 'SCR', 'SCRN', 'SCE', 'SCEN', 'SCD',
    'SCDN','SCQ', 'SCN']

PMF_popc='../../supp_files/popc/pmfs6/'
PMF_popc_data='../../supp_files/popc/distributions6/'
PMF_mono='../data/mono_data/popc-{}/pmfs/'
PMF_mono_data='../data/mono_data/popc-{}/distributions/'
save_dir='../plot/mono-nonmono/'

# %%
def free_energy(pKa, charge):
    R=8.314*10**(-3) #kJ/mol.K
    T=302.3545798089109 #K
    pH=7.0
    return -charge*R*T*np.log(10)*(pKa-pH)

def get_ref_per_acid(acid):
    #https://www.vanderbilt.edu/AnS/Chemistry/Rizzo/stuff/AA/AminoAcids.html
    # Pour la ref aux residus chargés
    #neutrals=['SCHE', 'SCHD', 'SCKN', 'SCRN', 'SCDN', 'SCEN', 'SCC']
    #pKas=[6.04, 6.04, 10.54, 12.48, 3.90, 4.07, 8.37]
    #charges=[1, 1, 1, 1, -1, -1, -1]
    # Pour la ref aux résidus non-chargés
    neutrals=['SCHP', 'SCKN', 'SCRN', 'SCDN', 'SCEN', 'SCCM', 'SCYM']
    pKas=[6.04, 10.54, 12.48, 3.90, 4.07, 8.37, 10.46]
    charges=[1, -1, -1, 1, 1, -1, -1]
    #dfref=extract_all_density(acid, file_path)
    #zero=stats_df['mean'].iloc[55]
    #zero=dfref['density{}{}'.format(traj, i)].values[55]+e #if per traj
    if acid in neutrals:
        zero_ref=free_energy(pKas[neutrals.index(acid)], charges[neutrals.index(acid)])
    else:
        zero_ref=0
    return zero_ref

def PMF_residue(acid, type):
    if type=='default':
        dfpmf=pd.read_table(PMF_popc+f'{acid}.dat'.lower(), sep="\s+")
    elif type=='mono' or type=='nonmono':
        dfpmf=pd.read_table(PMF_mono.format(type)+f'{acid}.dat'.lower(), sep="\s+")
    return dfpmf


def distribution_residue(acid, type):
    if type=='default':
        df=pd.read_table(PMF_popc_data+f'{acid}/trajectory1.dat'.lower(), sep="\s+", header=None, names=['x','y', 'e'])
    elif type=='mono' or type=='nonmono':
        df=pd.read_table(PMF_mono_data.format(type)+f'{acid}/trajectory1.dat'.lower(), sep="\s+", header=None, names=['x','y', 'e'])
    return df

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def plot_independent_graphs(acid_list, label_list, x_grid_interval=10, y_grid_interval=10):
    """
    Affiche des graphiques indépendants pour les PMF (ou profils de densité moyennés) d'acides.

    Paramètres:
      acid_list, label_list : listes imbriquées définissant pour chaque graphique indépendant
                              les acides et les labels correspondants.
                              Exemple pour 2 graphiques indépendants :
                                acid_list  = [['acid1', 'acid2'], ['acid3', 'acid4']]
                                label_list = [['label1', 'label2'], ['label3', 'label4']]
      x_grid_interval : int (défaut: 10)
                          Intervalle pour la grille verticale sur l'axe des abscisses.
      y_grid_interval : int (défaut: 10)
                          Intervalle pour la grille horizontale sur l'axe des ordonnées.
    """
    # Parcourir chaque groupe d'acides et leurs labels correspondants
    for group_acids, group_labels in zip(acid_list, label_list):
        fig, ax = plt.subplots(figsize=(5, 2))
        # Pour chaque acide dans le groupe, extraire les données et tracer sa courbe moyenne
        for acid, label in zip(group_acids, group_labels):
            # Extraction des données de pmf pour cet acide
            data1 = PMF_residue(acid, 'default')
            data2 = PMF_residue(acid, 'mono')
            data3 = PMF_residue(acid, 'nonmono')
            # Calcul de la courbe moyenne : moyenne de toutes les colonnes de densité, sauf '#z'
            #avg_curve = data.drop(columns=['#z']).mean(axis=1)
            x1, y1, e1 =data1['x'], data1['PMF_mean'], data1['std_error']
            x2, y2, e2 =data2['x'], data2['PMF_mean'], data2['std_error']
            x3, y3, e3 =data3['x'], data3['PMF_mean'], data3['std_error']
            ax.errorbar(x1, y1, e1, label=label, lw=2, linestyle='-', color='r')
            ax.errorbar(x2, y2, e2, label='mono', lw=1, linestyle='-', color='k')
            ax.errorbar(x3, y3, e3, label='multi', lw=1, linestyle='--', color='b')
        
        # Configuration de la grille verticale et horizontale
        #ax.xaxis.set_major_locator(ticker.MultipleLocator(x_grid_interval))
        #ax.yaxis.set_major_locator(ticker.MultipleLocator(y_grid_interval))
        ax.grid(True, which='major', linestyle='--', alpha=0.7)
        ax.set_xlim(0,35)
        
        # Ajout des labels et de la légende
        ax.set_xlabel("z (Å)")
        ax.set_ylabel("PMF (kJ/mol)")
        if group_labels[0] == 'CYS':
            ax.legend(loc='lower right', fontsize=8)
        else:
            ax.legend(fontsize=8)
        
        # Affichage du graphique
        plt.savefig(save_dir+'{}-pmf.png'.format(label), bbox_inches='tight', dpi=800, transparent=True)
        plt.show()


def plot_combined_graphs(acid_list, label_list, name, titrable=False, x_grid_interval=10, y_grid_interval=10):
    """
    Affiche des graphiques combinés en une seule colonne pour les PMF.
    
    Pour chaque sous-graphique, un groupe d'acides est tracé à partir des données extraites par
    extract_density(acid). Chaque courbe représente la moyenne des colonnes de densité (sauf '#z').
    
    Paramètres:
      acid_list, label_list : Listes imbriquées définissant, pour chaque sous-graphique, les acides
                              à combiner et leurs labels respectifs.
                              Exemple pour 2 sous-graphes combinés :
                                acid_list  = [['acid1', 'acid2'], ['acid3', 'acid4']]
                                label_list = [['label1', 'label2'], ['label3', 'label4']]
      x_grid_interval : int (défaut: 10)
                          Intervalle pour la grille verticale sur l'axe des abscisses.
      y_grid_interval : int (défaut: 10)
                          Intervalle pour la grille horizontale sur l'axe des ordonnées.
    """
    # Nombre de sous-graphes à créer (un par groupe d'acides)
    n_plots = len(acid_list)
    
    # Création des sous-graphes en une seule colonne, partageant le même axe x
    fig, axes = plt.subplots(n_plots, 1, sharex=True, figsize=(4.5, 1.2 * n_plots), gridspec_kw={'hspace': 0})
    fig.subplots_adjust(wspace=0, hspace=0)
    
    # Pour le cas d'un seul sous-graphe, s'assurer que axes est une liste
    if n_plots == 1:
        axes = [axes]
    
    # Parcours de chaque sous-graphique
    for ax, group_acids, group_labels in zip(axes, acid_list, label_list):
        # Pour chaque acide du groupe, extraire les données et tracer la courbe moyenne
        for acid, label in zip(group_acids, group_labels):
            # Extraction des données de pmf pour cet acide
            data1 = PMF_residue(acid, 'default')
            data2 = PMF_residue(acid, 'mono')
            data3 = PMF_residue(acid, 'nonmono')
            # Calcul de la courbe moyenne : moyenne de toutes les colonnes de densité, sauf '#z'
            #avg_curve = data.drop(columns=['#z']).mean(axis=1)
            if not titrable:
                x1, y1, e1 =data1['x'], data1['PMF_mean'], data1['std_error']
                x2, y2, e2 =data2['x'], data2['PMF_mean'], data2['std_error']
                x3, y3, e3 =data3['x'], data3['PMF_mean'], data3['std_error']
            else:
                correction = get_ref_per_acid(acid)
                x, y, e =data['x'], data['PMF_mean']+correction, data['std_error']
            ax.errorbar(x3, y3, e3, label='multi', lw=1, linestyle='--', color='b')
            ax.errorbar(x2, y2, e2, label='mono', lw=1, linestyle='-', color='k')
            ax.errorbar(x1, y1, e1, label=label, lw=2, linestyle='-', color='r')
            
                    
        # Configuration de la grille
        for spine in ax.spines.values():
            spine.set_linewidth(1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_grid_interval))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(y_grid_interval))
        ax.grid(True, which='major', linestyle='--', alpha=0.7)
        ax.set_xlim(0,35)
        """
        if 'CYS' in group_labels or 'ALA' in group_labels:
            ax.set_ylim(-25, 9)
            #ax.legend(fontsize=10, ncols=2, loc='lower right')
        elif 'THR' in group_labels:
            ax.set_ylim(-3, 23)
            #ax.legend(fontsize=10, ncols=2, loc='upper right')
        elif 'PHE' in group_labels:
            ax.set_ylim(-23, 15)
            #ax.legend(fontsize=10, ncols=3, loc='upper left')
        elif 'PRO' in group_labels:
            ax.set_ylim(-8, 23)
        elif 'TYR$^0$' in group_labels:
            ax.set_ylim(-18, 43)
        elif 'LYS$^0$' in group_labels:
            ax.set_ylim(-5, 33)
        elif 'CYS$^0$' in group_labels:
            ax.set_ylim(-13, 30)
        """
        ax.legend(fontsize=10, ncols=1, bbox_to_anchor=(1, 1), loc='upper left', borderaxespad=0., frameon=True, edgecolor='black', framealpha=0.8, markerscale=0.5)
        ax.tick_params(axis='both', which='major', labelsize=10)
        
        # Optionnel : ajouter un titre ou d'autres réglages propres à chaque sous-graphique
        #ax.set_ylabel("PMF")
    
    # Label commun pour l'axe x pour l'ensemble de la figure
    axes[-1].set_xlabel("z (Å)", fontsize=10)
    # Label commun pour l'axe y à gauche
    fig.text(0.04, 0.5, "PMF (kJ/mol)", va='center', rotation='vertical', fontsize=10)

    #fig.text(0.04, 1, name)
    
    plt.tight_layout(rect=[0.06, 0, 1, 1])  # Ajustement pour laisser de la place au label y commun
    plt.savefig(save_dir+'{}.png'.format(name), bbox_inches='tight', dpi=800) #, transparent=True)
    plt.show()

g1=['SCA', 'SCV', 'SCL', 'SCI']
g2=['SCC', 'SCM']
g3=['SCS', 'SCT', 'SCN', 'SCQ']
g4=['GLYD', 'SCP']
g5=['SCF', 'SCY', 'SCW']

l1=['ALA', 'VAL', 'LEU', 'ILE']
l2=['CYS', 'MET']
l3=['SER', 'THR', 'ASN', 'GLN']
l4=['GLYD', 'PRO']
l5=['PHE', 'TYR', 'TRP']

test1 = []
label1 = []
for a in aa:
    test1.append([a])
    label1.append([a])
#test1 = [g1, g2, g3, g5]
#test2 = [g1, g2, g3, g5, g4]

#label1 = [l1, l2, l3, l5]
#label2 = [l1, l2, l3, l5, l4]


#plot_independent_graphs(test1, label1)
#plot_independent_graphs(test2, label2)

plot_combined_graphs(test1, label1, 'all-pmf')
#plot_independent_graphs([['SCW']], [['TRP']])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 177
#     166     label1.append([a])
#     167 #test1 = [g1, g2, g3, g5]
#     168 #test2 = [g1, g2, g3, g5, g4]
#     169
#    (...)
#     174 #plot_independent_graphs(test1, label1)
#     175 #plot_independent_graphs(test2, label2)
# --> 177 plot_combined_graphs(test1, label1, 'all-pmf')
#     178 #plot_independent_graphs([['SCW']], [['TRP']])
#
# Cell In[10], line 91, in plot_combined_graphs(acid_list, label_list, name, titrable, x_grid_interval, y_grid_interval)
#      88 for acid, label in zip(group_acids, group_labels):
#      89     # Extraction des données de pmf pour cet acide
#      90     data1 = PMF_residue(acid, 'default')
# ---> 91     data2 = PMF_residue(acid, 'mono')
#      92     data3 = PMF_residue(acid, 'nonmono')
#      93     # Calcul de la courbe moyenne : moyenne de toutes les colonnes de densité, sauf '#z'
#      94     #avg_curve = data.drop(columns=['#z']).mean(axis=1)
#
# Cell In[7], line 30, in PMF_residue(acid, type)
#      28     dfpmf=pd.read_table(PMF_popc+f'{acid}.dat'.lower(), sep="\s+")
#      29 elif type=='mono' or type=='nonmono':
# ---> 30     dfpmf=pd.read_table(PMF_mono.format(type)+f'{acid}.dat'.lower(), sep="\s+")
#      31 return dfpmf
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1405, in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1392 kwds_defaults = _refine_defaults_read(
#    1393     dialect,
#    1394     delimiter,
#    (...)
#    1401     dtype_backend=dtype_backend,
#    1402 )
#    1403 kwds.update(kwds_defaults)
# -> 1405 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/mono_data/popc-mono/pmfs6/glyd.dat'

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def plot_independent_graphs(acid_list, label_list, x_grid_interval=10, y_grid_interval=10):
    """
    Affiche des graphiques indépendants pour les PMF (ou profils de densité moyennés) d'acides.

    Paramètres:
      acid_list, label_list : listes imbriquées définissant pour chaque graphique indépendant
                              les acides et les labels correspondants.
                              Exemple pour 2 graphiques indépendants :
                                acid_list  = [['acid1', 'acid2'], ['acid3', 'acid4']]
                                label_list = [['label1', 'label2'], ['label3', 'label4']]
      x_grid_interval : int (défaut: 10)
                          Intervalle pour la grille verticale sur l'axe des abscisses.
      y_grid_interval : int (défaut: 10)
                          Intervalle pour la grille horizontale sur l'axe des ordonnées.
    """
    # Parcourir chaque groupe d'acides et leurs labels correspondants
    for group_acids, group_labels in zip(acid_list, label_list):
        fig, ax = plt.subplots(figsize=(5, 2))
        # Pour chaque acide dans le groupe, extraire les données et tracer sa courbe moyenne
        for acid, label in zip(group_acids, group_labels):
            # Extraction des données de pmf pour cet acide
            data1 = distribution_residue(acid, 'default')
            data2 = distribution_residue(acid, 'mono')
            data3 = distribution_residue(acid, 'nonmono')
            # Calcul de la courbe moyenne : moyenne de toutes les colonnes de densité, sauf '#z'
            #avg_curve = data.drop(columns=['#z']).mean(axis=1)
            x1, y1, e1 =data1['x'], data1['y'], data1['e']
            x2, y2, e2 =data2['x'], data2['y'], data2['e']
            x3, y3, e3 =data3['x'], data3['y'], data3['e']
            ax.plot(x1, y1, label=label, lw=2, linestyle='-', color='r')
            ax.plot(x2, y2, label='mono', lw=1, linestyle='-', color='k')
            ax.plot(x3, e3, label='multi', lw=1, linestyle='--', color='b')
            
            
        
        # Configuration de la grille verticale et horizontale
        #ax.xaxis.set_major_locator(ticker.MultipleLocator(x_grid_interval))
        #ax.yaxis.set_major_locator(ticker.MultipleLocator(y_grid_interval))
        ax.grid(True, which='major', linestyle='--', alpha=0.7)
        ax.set_xlim(-50,50)
        
        # Ajout des labels et de la légende
        ax.set_xlabel("z (Å)")
        ax.set_ylabel("g(z)")
        if group_labels[0] == 'CYS':
            ax.legend(loc='lower right', fontsize=8)
        else:
            ax.legend(fontsize=8)
        
        # Affichage du graphique
        plt.savefig(save_dir+'{}-distrib.png'.format(label), bbox_inches='tight', dpi=800, transparent=True)
        plt.show()


def plot_combined_graphs(acid_list, label_list, name, titrable=False, x_grid_interval=10, y_grid_interval=10):
    """
    Affiche des graphiques combinés en une seule colonne pour les PMF.
    
    Pour chaque sous-graphique, un groupe d'acides est tracé à partir des données extraites par
    extract_density(acid). Chaque courbe représente la moyenne des colonnes de densité (sauf '#z').
    
    Paramètres:
      acid_list, label_list : Listes imbriquées définissant, pour chaque sous-graphique, les acides
                              à combiner et leurs labels respectifs.
                              Exemple pour 2 sous-graphes combinés :
                                acid_list  = [['acid1', 'acid2'], ['acid3', 'acid4']]
                                label_list = [['label1', 'label2'], ['label3', 'label4']]
      x_grid_interval : int (défaut: 10)
                          Intervalle pour la grille verticale sur l'axe des abscisses.
      y_grid_interval : int (défaut: 10)
                          Intervalle pour la grille horizontale sur l'axe des ordonnées.
    """
    # Nombre de sous-graphes à créer (un par groupe d'acides)
    n_plots = len(acid_list)
    
    # Création des sous-graphes en une seule colonne, partageant le même axe x
    fig, axes = plt.subplots(n_plots, 1, sharex=True, figsize=(4.5, 1.2 * n_plots), gridspec_kw={'hspace': 0})
    fig.subplots_adjust(wspace=0, hspace=0)
    
    # Pour le cas d'un seul sous-graphe, s'assurer que axes est une liste
    if n_plots == 1:
        axes = [axes]
    
    # Parcours de chaque sous-graphique
    for ax, group_acids, group_labels in zip(axes, acid_list, label_list):
        # Pour chaque acide du groupe, extraire les données et tracer la courbe moyenne
        for acid, label in zip(group_acids, group_labels):
            # Extraction des données de pmf pour cet acide
            data1 = distribution_residue(acid, 'default')
            data2 = distribution_residue(acid, 'mono')
            data3 = distribution_residue(acid, 'nonmono')
            # Calcul de la courbe moyenne : moyenne de toutes les colonnes de densité, sauf '#z'
            #avg_curve = data.drop(columns=['#z']).mean(axis=1)
            if not titrable:
                x1, y1, e1 =data1['x'], data1['y'], data1['e']
                x2, y2, e2 =data2['x'], data2['y'], data2['e']
                x3, y3, e3 =data3['x'], data3['y'], data3['e']
            else:
                correction = get_ref_per_acid(acid)
                x, y, e =data['x'], data['PMF_mean']+correction, data['std_error']
            ax.plot(x1, y1, label=label, lw=2, linestyle='-', color='r')
            ax.plot(x2, y2, label='mono', lw=1, linestyle='-', color='k')
            ax.plot(x3, e3, label='multi', lw=1, linestyle='--', color='b')
            #ax.plot((x2+x3)/2, (y2+e3)/2, label='mono+nonmono', lw=1, linestyle='--', color='g')
        
        # Configuration de la grille
        for spine in ax.spines.values():
            spine.set_linewidth(1)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_grid_interval))
        #ax.yaxis.set_major_locator(ticker.MultipleLocator(y_grid_interval))
        ax.grid(True, which='major', linestyle='--', alpha=0.7)
        ax.set_xlim(-35,35)
        """
        if 'CYS' in group_labels or 'ALA' in group_labels:
            ax.set_ylim(-25, 9)
            #ax.legend(fontsize=10, ncols=2, loc='lower right')
        elif 'THR' in group_labels:
            ax.set_ylim(-3, 23)
            #ax.legend(fontsize=10, ncols=2, loc='upper right')
        elif 'PHE' in group_labels:
            ax.set_ylim(-23, 15)
            #ax.legend(fontsize=10, ncols=3, loc='upper left')
        elif 'PRO' in group_labels:
            ax.set_ylim(-8, 23)
        elif 'TYR$^0$' in group_labels:
            ax.set_ylim(-18, 43)
        elif 'LYS$^0$' in group_labels:
            ax.set_ylim(-5, 33)
        elif 'CYS$^0$' in group_labels:
            ax.set_ylim(-13, 30)
        """
        ax.legend(fontsize=10, ncols=1, bbox_to_anchor=(1, 1), loc='upper left', borderaxespad=0., frameon=True, edgecolor='black', framealpha=0.8, markerscale=0.5)
        ax.tick_params(axis='both', which='major', labelsize=10)
        
        # Optionnel : ajouter un titre ou d'autres réglages propres à chaque sous-graphique
        #ax.set_ylabel("PMF")
    
    # Label commun pour l'axe x pour l'ensemble de la figure
    axes[-1].set_xlabel("z (Å)", fontsize=10)
    # Label commun pour l'axe y à gauche
    fig.text(0.04, 0.5, "g(z)", va='center', rotation='vertical', fontsize=10)

    #fig.text(0.04, 1, name)
    
    plt.tight_layout(rect=[0.06, 0, 1, 1])  # Ajustement pour laisser de la place au label y commun
    plt.savefig(save_dir+'{}.png'.format(name), bbox_inches='tight', dpi=800) #, transparent=True)
    plt.show()

g1=['SCA', 'SCV', 'SCL', 'SCI']
g2=['SCC', 'SCM']
g3=['SCS', 'SCT', 'SCN', 'SCQ']
g4=['GLYD', 'SCP']
g5=['SCF', 'SCY', 'SCW']

l1=['ALA', 'VAL', 'LEU', 'ILE']
l2=['CYS', 'MET']
l3=['SER', 'THR', 'ASN', 'GLN']
l4=['GLYD', 'PRO']
l5=['PHE', 'TYR', 'TRP']

test1 = []
label1 = []
for a in aa:
    test1.append([a])
    label1.append([a])
#test1 = [g1, g2, g3, g5]
#test2 = [g1, g2, g3, g5, g4]

#label1 = [l1, l2, l3, l5]
#label2 = [l1, l2, l3, l5, l4]


#plot_independent_graphs(test1, label1)
#plot_independent_graphs(test2, label2)

#plot_combined_graphs(test1, label1, 'all-distribution')
plot_independent_graphs([['SCA']], [['ALA']])

# %%
g1=['SCR', 'SCRN']
g2=['SCD', 'SCDN']
g3=['SCK', 'SCKN']
g4=['SCE', 'SCEN']
g5=['SCHE', 'SCHD', 'SCHP']
g6=['SCC', 'SCCM']
g7=['SCY', 'SCYM']
g8=['GLYD', 'SCP']

l1=['ARG$^+$', 'ARG$^0$']
l2=['ASP$^-$', 'ASP$^0$']
l3=['LYS$^+$', 'LYS$^0$']
l4=['GLU$^-$', 'GLU$^0$']
l5=['HSE$^0$', 'HSD$^0$', 'HSP$^+$']
l6=['CYS$^0$', 'CYS$^-$']
l7=['TYR$^0$', 'TYR$^-$']
l8=['GLYD', 'PRO']

test1 = [g6, g7, g2, g4, g3, g1, g5]

label1 = [l6, l7, l2, l4, l3, l1, l5]


#plot_independent_graphs(test1, label1)
#plot_independent_graphs(test2, label2)

plot_combined_graphs(test1, label1, '8_graphics_1col', titrable=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 27
#      21 label1 = [l6, l7, l2, l4, l3, l1, l5]
#      24 #plot_independent_graphs(test1, label1)
#      25 #plot_independent_graphs(test2, label2)
# ---> 27 plot_combined_graphs(test1, label1, '8_graphics_1col', titrable=True)
#
# Cell In[14], line 103, in plot_combined_graphs(acid_list, label_list, name, titrable, x_grid_interval, y_grid_interval)
#     101 else:
#     102     correction = get_ref_per_acid(acid)
# --> 103     x, y, e =data['x'], data['PMF_mean']+correction, data['std_error']
#     104 ax.plot(x1, y1, label=label, lw=2, linestyle='-', color='r')
#     105 ax.plot(x2, y2, label='mono', lw=1, linestyle='-', color='k')
#
# NameError: name 'data' is not defined

# %%
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

color = plt.rcParams['axes.prop_cycle'].by_key()['color']


def plot_combined_graphs_2col(acid_list, label_list, name,
                              x_grid_interval=10, y_grid_interval=10):
    """
    Affiche des graphiques combinés en 2 colonnes pour les PMF.
    
    acid_list, label_list : listes imbriquées, un sous-groupe par graphe.
    """
    n_plots = len(acid_list)
    n_rows = math.ceil(n_plots / 2)
    
    # Création d'une grille n_rows x 2
    fig, axes = plt.subplots(n_rows, 2, sharex=False,
                             figsize=(5, 1.8 * n_rows),
                             gridspec_kw={'hspace': 0, 'wspace' : 0}, sharey="row")
    
    axes_flat = axes.flatten()

    for idx, (group_acids, group_labels) in enumerate(zip(acid_list, label_list)):
        ax = axes_flat[idx]
        for spine in ax.spines.values():
            spine.set_linewidth(1)
        for acid, label in zip(group_acids, group_labels):
            data = PMF_residue(acid)
            correction = get_ref_per_acid(acid)
            x, y, e = data['x'], data['PMF_mean']+correction, data['std_error']
            if acid=='GLYD':
                ax.errorbar(x, y, e, label=label, lw=2, color=color[2])
            elif acid=='SCP':
                ax.errorbar(x, y, e, label=label, lw=2, color=color[3])
            else:
                ax.errorbar(x, y, e, label=label, lw=2)
        if 'SCC' in group_acids:
            ax.set_ylim(-12, 29)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_grid_interval))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(y_grid_interval))
        ax.grid(True, which='major', linestyle='--', alpha=0.7)
        ax.set_xlim(0, 35)
        ax.legend(fontsize=8, edgecolor='black', framealpha=0.8)
        if idx!=5 and idx!=6:
            ax.tick_params(labelbottom=False)
    
    # Si nombre de plots impair, cacher l'axe vide
    if n_plots % 2 == 1:
        #axes_flat[-1].set_visible(False)
        axes_flat[-1].set_visible(True)
        axes_flat[-1].set_xticklabels(new_labels)
    axes_flat[5].tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
    axes_flat[5].set_xlabel("z (Å)", fontsize=10)
    xticklabels = [label.get_text() for label in axes[2, 1].get_xticklabels()]
    new_labels = ["" if label == "0" else label for label in xticklabels]
    axes[2, 1].set_xticklabels(new_labels)
    axes_flat[6].set_xlabel("z (Å)", fontsize=10)


    # Labels communs
    fig.text(0.06, 0.5, "PMF (kJ/mol)",
             va='center', rotation='vertical', fontsize=10)
    fig.delaxes(axes_flat[7])
    
    plt.tight_layout(rect=[0.06, 0, 1, 1])
    plt.savefig(save_dir+f'{name}.png',
                bbox_inches='tight', dpi=800, transparent=True)
    plt.show()


g1=['SCR', 'SCRN']
g2=['SCD', 'SCDN']
g3=['SCK', 'SCKN']
g4=['SCE', 'SCEN']
g5=['SCHE', 'SCHD', 'SCHP']
g6=['SCC', 'SCCM']
g7=['SCY', 'SCYM']
g8=['GLYD', 'SCP']

l1=['ARG$^+$', 'ARG$^0$']
l2=['ASP$^-$', 'ASP$^0$']
l3=['LYS$^+$', 'LYS$^0$']
l4=['GLU$^-$', 'GLU$^0$']
l5=['HSE$^0$', 'HSD$^0$', 'HSP$^+$']
l6=['CYS$^0$', 'CYS$^+$']
l7=['TYR$^0$', 'TYR$^+$']
l8=['GLYD', 'PRO']

test1 = [g1, g3, g2, g4, g5, g6, g7, []] #g8

label1 = [l1, l3, l2, l4, l5, l6, l7, []] #l8



plot_combined_graphs_2col(test1, label1, '8_graphics')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 97
#      91 test1 = [g1, g3, g2, g4, g5, g6, g7, []] #g8
#      93 label1 = [l1, l3, l2, l4, l5, l6, l7, []] #l8
# ---> 97 plot_combined_graphs_2col(test1, label1, '8_graphics')
#
# Cell In[16], line 30, in plot_combined_graphs_2col(acid_list, label_list, name, x_grid_interval, y_grid_interval)
#      28     spine.set_linewidth(1)
#      29 for acid, label in zip(group_acids, group_labels):
# ---> 30     data = PMF_residue(acid)
#      31     correction = get_ref_per_acid(acid)
#      32     x, y, e = data['x'], data['PMF_mean']+correction, data['std_error']
#
# TypeError: PMF_residue() missing 1 required positional argument: 'type'

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

color = plt.rcParams['axes.prop_cycle'].by_key()['color']
fs=20

def plot_independent_graphs_v2(acid_list, label_list, plot_density=False, x_grid_interval=10, y_grid_interval=10):
    """
    Affiche des graphiques indépendants pour les PMF (ou profils de densité moyennés) d'acides.

    Paramètres:
      acid_list, label_list : listes imbriquées définissant pour chaque graphique indépendant
                              les acides et les labels correspondants.
                              Exemple pour 2 graphiques indépendants :
                                acid_list  = [['acid1', 'acid2'], ['acid3', 'acid4']]
                                label_list = [['label1', 'label2'], ['label3', 'label4']]
      x_grid_interval : int (défaut: 10)
                          Intervalle pour la grille verticale sur l'axe des abscisses.
      y_grid_interval : int (défaut: 10)
                          Intervalle pour la grille horizontale sur l'axe des ordonnées.
    """
    # Parcourir chaque groupe d'acides et leurs labels correspondants
    for group_acids, group_labels in zip(acid_list, label_list):
        fig, ax = plt.subplots(figsize=(7.75, 3))
        # Pour chaque acide dans le groupe, extraire les données et tracer sa courbe moyenne
        for acid, label in zip(group_acids, group_labels):
            if plot_density:
                all = pd.read_table(PMF_data+f'{acid}/trajectory3.dat'.lower(), sep="\s+", header=None, names=['x','y', 'e'])
                #display(all)
                x, y, e =all['x'], all['y'], all['e']
                ax.plot(x, y, label=label, lw=3)#, color=color[2])
            else:
                # Extraction des données de pmf pour cet acide
                all = pd.read_table(PMF_data+f'{acid}/trajectory3.dat'.lower(), sep="\s+", header=None, names=['x','y', 'e'])
                #display(all)
                x, y, e =all['x'], all['y'], all['e']
                ax.plot(x, e, label=label, lw=3)#, color=color[2])
        
        # Configuration de la grille verticale et horizontale
        ax.xaxis.set_major_locator(ticker.MultipleLocator(x_grid_interval))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(y_grid_interval))
        ax.grid(True, which='major', linestyle='--', alpha=0.7)
        ax.tick_params(axis='both', labelsize=fs)
        ax.set_xlim(0,55)
        
        # Ajout des labels et de la légende
        if plot_density:
            ax.set_xlabel("z (Å)", fontsize=fs)
            ax.set_ylabel("Density g$^\dagger$(z)", fontsize=fs)
        else:
            ax.set_xlabel("z (Å)", fontsize=fs)
            ax.set_ylabel("Density g$^\dagger$(z)", fontsize=fs)
        if group_labels[0] == 'CYS':
            ax.legend(loc='lower right', fontsize=fs)
        else:
            ax.legend(fontsize=fs)
        
        # Affichage du graphique
        if plot_density:
            plt.savefig(save_dir+'monomer.png', bbox_inches='tight', dpi=500, transparent=True)
        else:
            plt.savefig(save_dir+'nonmonomer.png', bbox_inches='tight', dpi=500, transparent=True)
        
        plt.show()


g1=['SCV', 'SCL', 'SCI', 'SCM', 'SCW']
l1=['VAL', 'LEU', 'ILE', 'MET', 'TRP']

test1 = [g1]

label1 = [l1]


#plot_independent_graphs(test1, label1)
PMF_data='../../supp_files/popc-mono/distributions/'
plot_independent_graphs_v2(test1, label1, plot_density=True, x_grid_interval=10, y_grid_interval=1)
PMF_data='../../supp_files/popc-nonmono/distributions/'
plot_independent_graphs_v2(test1, label1, plot_density=False, x_grid_interval=10, y_grid_interval=1)
#plot_independent_graphs_v2(test1, label1, plot_density=False)
