# %%
#from Bio.PDB import *
#from Bio.PDB.DSSP import DSSP
#from Bio.PDB.DSSP import dssp_dict_from_pdb_file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import MDAnalysis as mda
from MDAnalysis.lib.formats.libdcd import DCDFile

#dcd_file='/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/scripts/trajectory.dcd'
#faire 3 batch (1 de 400 à 600, 2 de 600 à 800, 3 de 800 à 1000)
dcd_file='/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/data/batch{}.dcd'
psf_file='/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/data/analog-{}.psf'

#coor_file='/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/{}.dat'

# %%
# Fonctions pour classifier les analogues en monomères, dimères et agrégats

from MDAnalysis.lib.distances import distance_array
from collections import defaultdict

def get_neighbor_graph(u, resname, cutoff=6.0):
    """
    Construit un graphe de voisinage entre les résidus d'un même type.
    
    Parameters:
    -----------
    u : MDAnalysis.Universe
    resname : str - nom du résidu (SCF, SCY, SCW, etc.)
    cutoff : float - distance seuil en Å
    
    Returns:
    --------
    dict : {resid: set(voisins_resids)}
    """
    # Tous les resids uniques
    all_resids = np.unique(u.select_atoms(f'resname {resname}').resids)
    
    # Graphe de voisinage
    neighbors = {resid: set() for resid in all_resids}
    
    # Pour chaque paire de résidus, vérifier s'ils sont voisins
    for i, resid1 in enumerate(all_resids):
        atoms1 = u.select_atoms(f'resname {resname} and resid {resid1} and not name H*')
        
        for resid2 in all_resids[i+1:]:
            atoms2 = u.select_atoms(f'resname {resname} and resid {resid2} and not name H*')
            
            # Distance minimale entre les deux résidus
            distances = distance_array(atoms1.positions, atoms2.positions)
            
            if distances.min() <= cutoff:
                neighbors[resid1].add(resid2)
                neighbors[resid2].add(resid1)
    
    return neighbors


def classify_residues(neighbors):
    """
    Classifie les résidus en monomères, dimères et agrégats.
    
    Parameters:
    -----------
    neighbors : dict - graphe de voisinage {resid: set(voisins)}
    
    Returns:
    --------
    list of tuples: [(resid, type, cluster_resids), ...]
        type: 'monomer', 'dimer', 'agregat'
        cluster_resids: liste des resid du cluster
    """
    results = []
    visited = set()
    
    for resid in neighbors:
        if resid in visited:
            continue
        
        n_neighbors = len(neighbors[resid])
        
        if n_neighbors == 0:
            # Monomère: pas de voisin
            results.append((resid, 'monomer', [resid]))
            visited.add(resid)
        
        elif n_neighbors == 1:
            # Potentiel dimère: vérifier que le voisin n'a qu'un seul voisin aussi
            neighbor = list(neighbors[resid])[0]
            
            if len(neighbors[neighbor]) == 1:
                # C'est un dimère!
                results.append((resid, 'dimer', sorted([resid, neighbor])))
                results.append((neighbor, 'dimer', sorted([resid, neighbor])))
                visited.add(resid)
                visited.add(neighbor)
            else:
                # Le voisin a plusieurs voisins -> fait partie d'un agrégat
                # On va le traiter dans la branche agrégat
                pass
        
        # Si pas encore visité (n_neighbors > 1 ou dimère raté), c'est un agrégat
        if resid not in visited:
            # BFS pour trouver tout le cluster
            cluster = set()
            queue = [resid]
            
            while queue:
                current = queue.pop(0)
                if current in cluster:
                    continue
                cluster.add(current)
                
                for neighbor in neighbors[current]:
                    if neighbor not in cluster:
                        queue.append(neighbor)
            
            # Tous les membres du cluster sont des agrégats
            cluster_list = sorted(cluster)
            for member in cluster:
                if member not in visited:
                    results.append((member, 'agregat', cluster_list))
                    visited.add(member)
    
    return results


def get_center_of_mass(u, resname, resid):
    """
    Calcule le centre de masse d'un résidu (atomes lourds uniquement).
    
    Parameters:
    -----------
    u : MDAnalysis.Universe
    resname : str
    resid : int
    
    Returns:
    --------
    np.array: coordonnées [x, y, z] du centre de masse
    """
    atoms = u.select_atoms(f'resname {resname} and resid {resid} and not name H*')
    return atoms.center_of_mass()


def analyze_frame(u, resname, cutoff=6.0):
    """
    Analyse une frame et retourne les classifications avec centres de masse.
    
    Returns:
    --------
    list of dicts: [{'frame', 'type', 'resid', 'x', 'y', 'z', 'cluster'}, ...]
    """
    frame = u.trajectory.frame
    
    # Construire le graphe de voisinage
    neighbors = get_neighbor_graph(u, resname, cutoff)
    
    # Classifier les résidus
    classifications = classify_residues(neighbors)
    
    # Calculer les centres de masse
    results = []
    for resid, mol_type, cluster in classifications:
        com = get_center_of_mass(u, resname, resid)
        results.append({
            'frame': frame,
            'type': mol_type,
            'resid': resid,
            'x': com[0],
            'y': com[1],
            'z': com[2],
            'cluster': cluster
        })
    
    return results

# %%
#get coordinates
def get_coord(structure):
    # Create an empty list to store atom coordinates
    atom_coordinates = []

    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    atom_coordinates.append(atom.get_coord())
    return atom_coordinates

def get_ca_coord(structure):
    # Create an empty list to store atom coordinates
    calpha_atoms = []

    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                   if atom.get_name()=="CA":
                       calpha_atoms.append(atom) 
    CA_coordinates = [atom.get_coord() for atom in calpha_atoms]
    return CA_coordinates

#save new coordinates
def update(structure, modified_coordinates):
    # Update the atom coordinates in the structure:
    atom_index = 0

    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    # Update the atom coordinates in the structure
                    atom.set_coord(modified_coordinates[atom_index])
                    atom_index += 1
    return structure

# %%
def nglplot(x):
    traj = pt.load('./'+x)
    view = nv.show_pytraj(traj)

# %%
def regressi_vector(x, y, z):
    #determine a vector of the regression
    x1=np.column_stack((x,z))
    model = linear_model.LinearRegression()
    #print(x1, y)
    model.fit(x1,y)
    v1 = [model.coef_[0], 1, model.coef_[1]]
    return v1 / np.linalg.norm(v1) #vecteur unitaire
    #vecteur_directeur = np.array([reg.coef_[0], reg.coef_[1], reg.coef_[2]])

def angle_between(v1, v2):
    #v1 et v2 doivent être des vecteurs unitaires
    return np.arccos(np.clip(np.dot(v1, v2), -1.0, 1.0))


def angle_with_normal(structure, TM, v2):
    #calculate angle between the vector and the normal of the membrane
    x, y, z = get_ca_coord_part(structure, TM)
    v1=regressi_vector(x, y, z)
    return angle_between(v1, v2)

# %%
# Extraction des centres de masse classifiés en monomères, dimères et agrégats

#scs = ['SCV', 'SCI', 'SCL', 'SCM', 'SCF', 'SCY', 'SCW']
#scs = ['SCRN']
scs = ['SCA', 'SCC', 'SCS', 'SCT', 'SCQ', 'SCN', 'GLYD', 'SCP', 'SCCM', 'SCYM', 'SCD', 'SCDN', 'SCE', 'SCEN', 'SCR', 'SCRN', 'SCK', 'SCKN', 'SCHD', 'SCHE', 'SCHP']
cutoff = 6.0
#faire SCRN traj3 batch3
# Fichier de sortie modifié
output_file_template = '/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/data/com_classified_{}.dat'


for sc in scs:
    output_file_template = '/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/data/com_classified_{}.dat'
    trajs = [1, 2, 3]
    suffix=''

    if sc == 'SCW' or sc == 'SCV' or sc == 'GLYD' or sc == 'SCA' or sc == 'SCP':
        trajs = [4, 2, 3]
        
    elif sc == 'SCHP' or sc == 'SCK' or sc == 'SCR' or sc == 'SCCM' or sc == 'SCD' or sc == 'SCE':
        suffix='-N'
    
    elif sc == 'SCYM':
        trajs = [4, 2, 6]
    
    for traj_idx in trajs:
        for k in range(1, 4):
            u = mda.Universe(psf_file.format(sc+suffix, traj_idx, sc), dcd_file.format(sc+suffix, traj_idx, k))
            print(f'\n=== {sc} traj{traj_idx} batch{k} ===')
            print(u)
            
            # Collecter toutes les données
            all_data = []
            
            for ts in u.trajectory:
                fr = ts.frame
                if fr % 1000 == 0:
                    print(f'Frame {fr//1000}/20')
                
                # Analyser la frame
                frame_results = analyze_frame(u, sc, cutoff)
                all_data.extend(frame_results)
            
            # Créer le DataFrame
            df = pd.DataFrame(all_data)
            
            # Convertir la colonne cluster en string pour sauvegarde
            df['cluster_str'] = df['cluster'].apply(lambda x: '_'.join(map(str, x)))
            
            # Statistiques
            n_mono = len(df[df['type'] == 'monomer'])
            n_dimer = len(df[df['type'] == 'dimer'])
            n_agreg = len(df[df['type'] == 'agregat'])
            print(f'  Monomères: {n_mono}')
            print(f'  Dimères: {n_dimer}')
            print(f'  Agrégats: {n_agreg}')
            
            # Sauvegarder
            output_file = output_file_template.format(sc+suffix, traj_idx, k)
            
            # Format: frame type resid x y z cluster
            with open(output_file, 'w') as f:
                f.write('#frame type resid x y z cluster\n')
                for _, row in df.iterrows():
                    f.write(f"{row['frame']} {row['type']} {row['resid']} "
                            f"{row['x']:.6f} {row['y']:.6f} {row['z']:.6f} "
                            f"{row['cluster_str']}\n")
            
            print(f'  Saved: {output_file}')

print("\nC'est bon, j'ai fini !!!")
# Out:
# === SCA traj4 batch1 ===
# <Universe with 130 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 375087
#   Dimères: 91580
#   Agrégats: 53333
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj4/data/com_classified_1.dat
#
# === SCA traj4 batch2 ===
# <Universe with 130 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 381801
#   Dimères: 89464
#   Agrégats: 48735
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj4/data/com_classified_2.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCA traj4 batch3 ===
# <Universe with 130 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 362156
#   Dimères: 97960
#   Agrégats: 62484
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj4/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCA traj2 batch1 ===
# <Universe with 130 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 371609
#   Dimères: 92240
#   Agrégats: 56151
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj2/data/com_classified_1.dat
#
# === SCA traj2 batch2 ===
# <Universe with 130 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 378506
#   Dimères: 90574
#   Agrégats: 50920
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj2/data/com_classified_2.dat
#
# === SCA traj2 batch3 ===
# <Universe with 130 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 386731
#   Dimères: 88892
#   Agrégats: 46977
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj2/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCA traj3 batch1 ===
# <Universe with 130 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 367297
#   Dimères: 95474
#   Agrégats: 57229
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj3/data/com_classified_1.dat
#
# === SCA traj3 batch2 ===
# <Universe with 130 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 356922
#   Dimères: 99624
#   Agrégats: 63454
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj3/data/com_classified_2.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCA traj3 batch3 ===
# <Universe with 130 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 375211
#   Dimères: 92866
#   Agrégats: 54523
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCA/analyses/traj3/data/com_classified_3.dat
#
# === SCC traj1 batch1 ===
# <Universe with 156 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 369561
#   Dimères: 101062
#   Agrégats: 49377
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj1/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCC traj1 batch2 ===
# <Universe with 156 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 350009
#   Dimères: 108588
#   Agrégats: 61403
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj1/data/com_classified_2.dat
#
# === SCC traj1 batch3 ===
# <Universe with 156 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 353866
#   Dimères: 110210
#   Agrégats: 58524
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj1/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCC traj2 batch1 ===
# <Universe with 156 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 362897
#   Dimères: 103476
#   Agrégats: 53627
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj2/data/com_classified_1.dat
#
# === SCC traj2 batch2 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 375086
#   Dimères: 97014
#   Agrégats: 47900
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj2/data/com_classified_2.dat
#
# === SCC traj2 batch3 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 353950
#   Dimères: 108038
#   Agrégats: 60612
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj2/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCC traj3 batch1 ===
# <Universe with 156 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 367326
#   Dimères: 101398
#   Agrégats: 51276
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj3/data/com_classified_1.dat
#
# === SCC traj3 batch2 ===
# <Universe with 156 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 366350
#   Dimères: 104184
#   Agrégats: 49466
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj3/data/com_classified_2.dat
#
# === SCC traj3 batch3 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 376045
#   Dimères: 96810
#   Agrégats: 49745
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCC/analyses/traj3/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCS traj1 batch1 ===
# <Universe with 156 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 460392
#   Dimères: 52408
#   Agrégats: 7200
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj1/data/com_classified_1.dat
#
# === SCS traj1 batch2 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 461622
#   Dimères: 51238
#   Agrégats: 7140
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj1/data/com_classified_2.dat
#
# === SCS traj1 batch3 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 462778
#   Dimères: 50634
#   Agrégats: 7108
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj1/data/com_classified_3.dat
#
# === SCS traj2 batch1 ===
# <Universe with 156 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 462672
#   Dimères: 50452
#   Agrégats: 6876
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj2/data/com_classified_1.dat
#
# === SCS traj2 batch2 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 461739
#   Dimères: 51422
#   Agrégats: 6839
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj2/data/com_classified_2.dat
#
# === SCS traj2 batch3 ===
# <Universe with 156 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 463778
#   Dimères: 51694
#   Agrégats: 7128
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj2/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCS traj3 batch1 ===
# <Universe with 156 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 459891
#   Dimères: 52430
#   Agrégats: 7679
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj3/data/com_classified_1.dat
#
# === SCS traj3 batch2 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 462884
#   Dimères: 49998
#   Agrégats: 7118
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj3/data/com_classified_2.dat
#
# === SCS traj3 batch3 ===
# <Universe with 156 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 464496
#   Dimères: 51078
#   Agrégats: 7026
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCS/analyses/traj3/data/com_classified_3.dat
#
# === SCT traj1 batch1 ===
# <Universe with 234 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 449857
#   Dimères: 60000
#   Agrégats: 10143
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj1/data/com_classified_1.dat
#
# === SCT traj1 batch2 ===
# <Universe with 234 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 448205
#   Dimères: 61056
#   Agrégats: 10739
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj1/data/com_classified_2.dat
#
# === SCT traj1 batch3 ===
# <Universe with 234 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 453315
#   Dimères: 59468
#   Agrégats: 9817
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj1/data/com_classified_3.dat
#
# === SCT traj2 batch1 ===
# <Universe with 234 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 450527
#   Dimères: 59548
#   Agrégats: 9925
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj2/data/com_classified_1.dat
#
# === SCT traj2 batch2 ===
# <Universe with 234 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 446249
#   Dimères: 63454
#   Agrégats: 10297
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj2/data/com_classified_2.dat
#
# === SCT traj2 batch3 ===
# <Universe with 234 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 453052
#   Dimères: 59696
#   Agrégats: 9852
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj2/data/com_classified_3.dat
#
# === SCT traj3 batch1 ===
# <Universe with 234 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 450322
#   Dimères: 58928
#   Agrégats: 10750
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj3/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCT traj3 batch2 ===
# <Universe with 234 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 449400
#   Dimères: 60564
#   Agrégats: 10036
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj3/data/com_classified_2.dat
#
# === SCT traj3 batch3 ===
# <Universe with 234 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 450300
#   Dimères: 61556
#   Agrégats: 10744
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCT/analyses/traj3/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCQ traj1 batch1 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 415983
#   Dimères: 82910
#   Agrégats: 21107
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj1/data/com_classified_1.dat
#
# === SCQ traj1 batch2 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 418253
#   Dimères: 80776
#   Agrégats: 20971
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj1/data/com_classified_2.dat
#
# === SCQ traj1 batch3 ===
# <Universe with 312 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 421642
#   Dimères: 78430
#   Agrégats: 22528
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj1/data/com_classified_3.dat
#
# === SCQ traj2 batch1 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 417843
#   Dimères: 81170
#   Agrégats: 20987
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj2/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCQ traj2 batch2 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 418291
#   Dimères: 79238
#   Agrégats: 22471
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj2/data/com_classified_2.dat
#
# === SCQ traj2 batch3 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 425897
#   Dimères: 76028
#   Agrégats: 20675
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj2/data/com_classified_3.dat
#
# === SCQ traj3 batch1 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 417985
#   Dimères: 80594
#   Agrégats: 21421
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj3/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCQ traj3 batch2 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 421507
#   Dimères: 77324
#   Agrégats: 21169
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj3/data/com_classified_2.dat
#
# === SCQ traj3 batch3 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 421792
#   Dimères: 78408
#   Agrégats: 22400
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCQ/analyses/traj3/data/com_classified_3.dat
#
# === SCN traj1 batch1 ===
# <Universe with 234 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 435462
#   Dimères: 69292
#   Agrégats: 15246
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCN/analyses/traj1/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCN traj1 batch2 ===
# <Universe with 234 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 433851
#   Dimères: 70350
#   Agrégats: 15799
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCN/analyses/traj1/data/com_classified_2.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCN traj1 batch3 ===
# <Universe with 234 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 436251
#   Dimères: 69536
#   Agrégats: 16813
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCN/analyses/traj1/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCN traj2 batch1 ===
# <Universe with 234 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 432801
#   Dimères: 71076
#   Agrégats: 16123
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCN/analyses/traj2/data/com_classified_1.dat
#
# === SCN traj2 batch2 ===
# <Universe with 234 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 429337
#   Dimères: 74154
#   Agrégats: 16509
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCN/analyses/traj2/data/com_classified_2.dat
#
# === SCN traj2 batch3 ===
# <Universe with 234 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 436869
#   Dimères: 70246
#   Agrégats: 15485
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCN/analyses/traj2/data/com_classified_3.dat
# ...
# Frame 19/20
# Frame 20/20
#   Monomères: 420678
#   Dimères: 79362
#   Agrégats: 22560
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHD/analyses/traj3/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCHE traj1 batch1 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 419439
#   Dimères: 79296
#   Agrégats: 21265
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj1/data/com_classified_1.dat
#
# === SCHE traj1 batch2 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 420367
#   Dimères: 78264
#   Agrégats: 21369
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj1/data/com_classified_2.dat
#
# === SCHE traj1 batch3 ===
# <Universe with 312 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 419317
#   Dimères: 80062
#   Agrégats: 23221
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj1/data/com_classified_3.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCHE traj2 batch1 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 418610
#   Dimères: 79556
#   Agrégats: 21834
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj2/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCHE traj2 batch2 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 420842
#   Dimères: 77710
#   Agrégats: 21448
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj2/data/com_classified_2.dat
#
# === SCHE traj2 batch3 ===
# <Universe with 312 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 424938
#   Dimères: 77100
#   Agrégats: 20562
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj2/data/com_classified_3.dat
#
# === SCHE traj3 batch1 ===
# <Universe with 312 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 418153
#   Dimères: 79102
#   Agrégats: 22745
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj3/data/com_classified_1.dat
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# === SCHE traj3 batch2 ===
# <Universe with 312 atoms>
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 417871
#   Dimères: 78816
#   Agrégats: 23313
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj3/data/com_classified_2.dat
#
# === SCHE traj3 batch3 ===
# <Universe with 312 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 422842
#   Dimères: 78928
#   Agrégats: 20830
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHE/analyses/traj3/data/com_classified_3.dat
#
# === SCHP traj1 batch1 ===
# <Universe with 338 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 467400
#   Dimères: 47554
#   Agrégats: 5046
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj1/data/com_classified_1.dat
#
# === SCHP traj1 batch2 ===
# <Universe with 338 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 465747
#   Dimères: 49010
#   Agrégats: 5243
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj1/data/com_classified_2.dat
#
# === SCHP traj1 batch3 ===
# <Universe with 338 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 470364
#   Dimères: 47152
#   Agrégats: 5084
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj1/data/com_classified_3.dat
#
# === SCHP traj2 batch1 ===
# <Universe with 338 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 468792
#   Dimères: 46340
#   Agrégats: 4868
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj2/data/com_classified_1.dat
#
# === SCHP traj2 batch2 ===
# <Universe with 338 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 467774
#   Dimères: 46826
#   Agrégats: 5400
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj2/data/com_classified_2.dat
#
# === SCHP traj2 batch3 ===
# <Universe with 338 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
# Frame 20/20
#   Monomères: 471331
#   Dimères: 46106
#   Agrégats: 5163
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj2/data/com_classified_3.dat
#
# === SCHP traj3 batch1 ===
# <Universe with 338 atoms>
# Frame 0/20
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20
# Frame 13/20
# Frame 14/20
# Frame 15/20
# Frame 16/20
# Frame 17/20
# Frame 18/20
# Frame 19/20
#   Monomères: 469288
#   Dimères: 46138
#   Agrégats: 4574
#   Saved: /media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-SCHP-N/analyses/traj3/data/com_classified_1.dat
#
# === SCHP traj3 batch2 ===
# <Universe with 338 atoms>
# /home/bories/anaconda3/lib/python3.9/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Frame 0/20
# Frame 1/20
# Frame 2/20
# Frame 3/20
# Frame 4/20
# Frame 5/20
# Frame 6/20
# Frame 7/20
# Frame 8/20
# Frame 9/20
# Frame 10/20
# Frame 11/20
# Frame 12/20

# %%
# Extraction des centres de masse classifiés en monomères, dimères et agrégats

#scs = ['SCV', 'SCI', 'SCL', 'SCM', 'SCF', 'SCY', 'SCW']
scs = ['SCYM']
#scs = ['SCA', 'SCC', 'SCS', 'SCT', 'SCQ', 'SCN', 'GLYD', 'SCP', 'SCCM', 'SCYM', 'SCD', 'SCDN', 'SCE', 'SCEN', 'SCR', 'SCRN', 'SCK', 'SCKN', 'SCHD', 'SCHE', 'SCHP']
cutoff = 6.0
#faire SCRN traj3 batch3
# Fichier de sortie modifié
output_file_template = '/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/data/com_classified_{}.dat'


for sc in scs:
    output_file_template = '/media/bories/Backup/bories/Documents/Travail/results/homoPOPC-aa/homoPOPC-{}/analyses/traj{}/data/com_classified_{}.dat'
    trajs = [1, 2, 3]
    suffix=''

    if sc == 'SCW' or sc == 'SCV' or sc == 'GLYD' or sc == 'SCA' or sc == 'SCP':
        trajs = [4, 2, 3]
        
    elif sc == 'SCHP' or sc == 'SCK' or sc == 'SCR' or sc == 'SCCM' or sc == 'SCD' or sc == 'SCE':
        suffix='-N'
    
    elif sc == 'SCYM':
        trajs = [5]
    
    for traj_idx in trajs:
        for k in range(1, 4):
            u = mda.Universe(psf_file.format(sc+suffix, traj_idx, sc), dcd_file.format(sc+suffix, traj_idx, k))
            print(f'\n=== {sc} traj{traj_idx} batch{k} ===')
            print(u)
            
            # Collecter toutes les données
            all_data = []
            
            for ts in u.trajectory:
                fr = ts.frame
                if fr % 1000 == 0:
                    print(f'Frame {fr//1000}/20')
                
                # Analyser la frame
                frame_results = analyze_frame(u, sc, cutoff)
                all_data.extend(frame_results)
            
            # Créer le DataFrame
            df = pd.DataFrame(all_data)
            
            # Convertir la colonne cluster en string pour sauvegarde
            df['cluster_str'] = df['cluster'].apply(lambda x: '_'.join(map(str, x)))
            
            # Statistiques
            n_mono = len(df[df['type'] == 'monomer'])
            n_dimer = len(df[df['type'] == 'dimer'])
            n_agreg = len(df[df['type'] == 'agregat'])
            print(f'  Monomères: {n_mono}')
            print(f'  Dimères: {n_dimer}')
            print(f'  Agrégats: {n_agreg}')
            
            # Sauvegarder
            output_file = output_file_template.format(sc+suffix, traj_idx, k)
            
            # Format: frame type resid x y z cluster
            with open(output_file, 'w') as f:
                f.write('#frame type resid x y z cluster\n')
                for _, row in df.iterrows():
                    f.write(f"{row['frame']} {row['type']} {row['resid']} "
                            f"{row['x']:.6f} {row['y']:.6f} {row['z']:.6f} "
                            f"{row['cluster_str']}\n")
            
            print(f'  Saved: {output_file}')

print("\nC'est bon, j'ai fini !!!")
